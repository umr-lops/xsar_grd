# %%
from xsargrd import load_config, generate_l1c

# %%
# --- parameters ---
config_id = 'J01'
filename = "/home/datawork-cersat-public/cache/project/sarwave/data/products/experiments/grd/rcm1/sc100ma/l1b/2022/269/RCM1_OK2378142_PK2381309_1_SC100MA_20220926_112612_VV_VH_GRD"

# --- load config ---
cfg = load_config()[config_id]
res = cfg['res']
ancillary_list = cfg['auxilliary_dataset']

# --- generate L1C ---
l1c_ds, flags = generate_l1c(filename, res, ancillary_list, save=False, overwrite=True)
# Out:
# INFO:xsargrd.l1c.generate:[L1C] Starting L1C generation
# INFO:xsargrd.l1c.generate:[IO] Ancillary inputs: ['ecmwf_0100_1h', 'ww3_global_yearly_3h']
# INFO:xsargrd.l1c.generate:[IO] Searching L1B files in: /home/datawork-cersat-public/cache/project/sarwave/data/products/experiments/grd/rcm1/sc100ma/l1b/2022/269/RCM1_OK2378142_PK2381309_1_SC100MA_20220926_112612_VV_VH_GRD/res100m
# INFO:xsargrd.l1c.generate:[IO] Number of L1B files found: 1
# INFO:xsargrd.l1c.generate:[L1C] Processing L1B file: rcm1_ok2378142_pk2381309_1_sc100ma_20220926_112612_vv_vh_grd_j01.nc
# INFO:xsargrd.l1c.generate:[L1C] Enriching L1B with ancillary data...
# INFO:xsargrd.l1c.pipeline:[Ancillary] Opening L1B dataset: /home/datawork-cersat-public/cache/project/sarwave/data/products/experiments/grd/rcm1/sc100ma/l1b/2022/269/RCM1_OK2378142_PK2381309_1_SC100MA_20220926_112612_VV_VH_GRD/res100m/rcm1_ok2378142_pk2381309_1_sc100ma_20220926_112612_vv_vh_grd_j01.nc
# ...
