# %%
from xsargrd import load_config, generate_l1b

# %%
# --- parameters ---
config_id = 'J01'
filename = "/home/datawork-cersat-public/provider/csa/satellite/l1/rcm/rcm-1/sc100ma/2022/269/RCM1_OK2378142_PK2381309_1_SC100MA_20220926_112612_VV_VH_GRD"
filename = "/home/datawork-cersat-public/cache/project/sarwing/data/RS2/L1/VV_VH/2024/311/RS2_OK162180_PK1474419_DK1439752_SCWA_20241106_234006_VV_VH_SGF"

# --- select config ---
c = load_config()[config_id]

# --- generate L1B ---
l1b_rcm_ds = generate_l1b(
    filename,
    dirout=c["dirout"],
    res=c["res"],
    tile_size=c["tile_size"],
    periodo_width=c["periodo_width"],
    periodo_overlap=c["periodo_overlap"],
    lowpass_width=c["lowpass_width"],
    scatt_mode=c["scatt_mode"],
    norient=c["norient"],
    save=False,
    config_id=config_id,
)
# Out:
# INFO:xsargrd.l1b.generate:[Tile] Generating tiles from input product...
# INFO:xsar.utils:BlockingActorProxy: Transparent proxy for RadarSat2Meta
# INFO:grdtiler.grdtiler:Start tiling...
# ...
# Adding footprints: 100%|██████████| 870/870 [03:52<00:00,  3.74it/s]
# INFO:grdtiler.grdtiler:Done tiling...
# INFO:xsargrd.l1b.generate:[Tile] Tiles generated.
# INFO:xsargrd.l1b.generate:[Tile] Checking ocean-only mask...
# Create ocean-only mask: 100%|██████████| 870/870 [04:06<00:00,  3.53tile/s]
# /home1/datahome/egauvrit/conda-env/sar_env/lib/python3.11/site-packages/dask/_task_spec.py:768: RuntimeWarning: invalid value encountered in divide
#   return self.func(*new_argspec)
# INFO:xsargrd.l1b.generate:[Tile] Ocean-only mask applied. 731 tiles remain after filtering.
# INFO:xsargrd.l1b.generate:[Tile] Loaded 731 tiles.
# INFO:xsargrd.l1b.generate:[Tile] Removing bright targets from tiles...
# ...
